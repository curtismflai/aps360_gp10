# %%
#importing neccesary things
import numpy as np
import torch
import torch.nn as nn
import torch.utils.data as data_utils
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt

# %%
import os
from os import listdir

# %%
def load_sample(path, num_image):
    #load sample data for debugging
    sample_numpy = []
    for i in range(num_image):
            image = plt.imread("{}/{:03d}.jpg".format(path, i+1))
            sample_numpy.append(image)
    return sample_numpy

# %%
resized_images = load_sample("resized", 50)
original_images = load_sample("Images", 50)

# %%
plt.subplot(1, 2, 1)
plt.imshow(original_images[0])
plt.subplot(1, 2, 2)
plt.imshow(resized_images[0])
